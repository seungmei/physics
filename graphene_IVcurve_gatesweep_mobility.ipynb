# %% [markdown]
# <a href="https://colab.research.google.com/github/seungmei/suh_lab/blob/main/graphene_IVcurve_gatesweep_mobility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 필요한 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # IV curve

# %%
file_IV = '/content/drive/MyDrive/2023_서동석교수님_랩인턴/측정/1. SMH_IV_0.01 cd test'

# 데이터프레임 생성
IV = pd.read_csv(file_IV, header=None, sep ='\t', names = ['Time', 'Vsd', 'Isd', 'R', 'Vg', 'Ileak'])
IV
# Out:
#          Time    Vsd           Isd         R   Vg         Ileak
# 0    2.286241  0.000  3.249602e-07       inf  0.0 -1.943431e-11
# 1    2.756226  0.001  1.859586e-06  0.001860  0.0 -2.000426e-11
# 2    3.237830  0.002  3.385086e-06  0.001693  0.0 -2.007487e-11
# 3    3.718021  0.003  4.915757e-06  0.001639  0.0 -2.008496e-11
# 4    4.198130  0.004  6.454717e-06  0.001614  0.0 -1.930822e-11
# 5    4.677677  0.005  7.974107e-06  0.001595  0.0 -2.027662e-11
# 6    5.157500  0.006  9.498097e-06  0.001583  0.0 -2.020097e-11
# 7    5.638316  0.007  1.102525e-05  0.001575  0.0 -2.022114e-11
# 8    6.116721  0.008  1.255009e-05  0.001569  0.0 -2.000929e-11
# 9    6.585633  0.009  1.408006e-05  0.001564  0.0 -1.998408e-11
# 10   7.068629  0.010  1.560384e-05  0.001560  0.0 -2.043298e-11
# 11   7.548471  0.009  1.407979e-05  0.001564  0.0 -2.033211e-11
# 12   8.026649  0.008  1.255577e-05  0.001569  0.0 -2.047837e-11
# 13   8.508382  0.007  1.101329e-05  0.001573  0.0 -2.077597e-11
# ...

# %%
import matplotlib.pyplot as plt

# Plotting Isd with lines and markers
plt.plot(IV['Vsd'], IV['Isd']*1e6, label='Isd', marker='.', linestyle='-', color='darkgrey', linewidth=0.5)

# Adding labels and title
plt.xlabel('$V_{sd}$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.title('Isd vs Vsd with Lines and Markers')

# Display the plot
plt.show()

# %% [markdown]
# # gate-sweep

# %%
file_sweep = '/content/drive/MyDrive/2023_서동석교수님_랩인턴/측정/4. SMH_Vg_0.01 cd'

# 데이터프레임 생성
# df = pd.DataFrame(np.loadtxt(file))
GW = pd.read_csv(file_sweep, header=None, sep ='\t', names = ['Time', 'Vg', 'Iㅣeak', 'Vsd', 'Isd', 'R'])
GW
# Out:
#            Time   Vg         Iㅣeak   Vsd       Isd         R
# 0      7.105096  0.0 -1.074834e-10  0.01  0.000016  644.5147
# 1      9.486370  1.0 -8.998591e-11  0.01  0.000015  650.4467
# 2      9.878807  2.0 -7.940659e-11  0.01  0.000015  656.3174
# 3     10.268550  3.0 -7.111126e-11  0.01  0.000015  663.0451
# 4     10.658210  4.0 -6.505785e-11  0.01  0.000015  669.1470
# ..          ...  ...           ...   ...       ...       ...
# 713  291.337700  4.0 -1.900488e-10  0.01  0.000015  657.8272
# 714  291.759200  3.0 -1.882681e-10  0.01  0.000015  652.3527
# 715  292.173600  2.0 -1.878143e-10  0.01  0.000015  646.6477
# 716  292.572000  1.0 -1.910677e-10  0.01  0.000016  641.3233
# 717  292.972800  0.0 -1.886235e-10  0.01  0.000016  635.2937
#
# [718 rows x 6 columns]

# %% [markdown]
# ## 일단 단순히 scatter plot을 해보자.

# %%
import matplotlib.pyplot as plt

# Plotting Isd with lines and markers
plt.plot(GW['Vg'], GW['Isd']*1e6, label='Isd', marker='o', linestyle='-', color='blue', linewidth=0.8)

# Adding labels and title
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.title('Isd vs Vg with Lines and Markers')
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ## gate sweep 구간별로 split 후에 그래프를 plot 해보자.
# ### gate sweep 구간별로 split 해주기 위해 규칙을 알아보니 gate sweep 구간이 21개의 행으로 시작하여 다음 구간으로 넘어갈때마다 20개씩 데이터의 행이 증가하는 규칙이 있음을 알 수 있다.

# %%
import pandas as pd

# Assuming your original DataFrame is named 'df'
# You can replace 'df' with the actual name of your DataFrame if it's different

# Create a list to store the split DataFrames
split_dfs = []

# Set the initial index and the step size
index = 0
step_size = 21

# Iterate through the rows and split the DataFrame
while index < len(GW):
    split_dfs.append(GW.iloc[index:index+step_size])
    index += step_size
    step_size += 20  # Increase the step size for the next split DataFrame

# Create new DataFrame names (df1, df2, df3, ...)
df_names = [f'gate_sweep{i+1}' for i in range(len(split_dfs))]

# Assign the split DataFrames to the new names
for name, split_df in zip(df_names, split_dfs):
    globals()[name] = split_df

# %%
gate_sweep1
# Out:
#          Time    Vg         Iㅣeak   Vsd       Isd         R
# 0    7.105096   0.0 -1.074834e-10  0.01  0.000016  644.5147
# 1    9.486370   1.0 -8.998591e-11  0.01  0.000015  650.4467
# 2    9.878807   2.0 -7.940659e-11  0.01  0.000015  656.3174
# 3   10.268550   3.0 -7.111126e-11  0.01  0.000015  663.0451
# 4   10.658210   4.0 -6.505785e-11  0.01  0.000015  669.1470
# 5   11.048350   5.0 -6.541412e-11  0.01  0.000015  675.0768
# 6   11.438850   6.0 -5.778378e-11  0.01  0.000015  682.7476
# 7   11.827850   7.0 -5.773310e-11  0.01  0.000015  689.3519
# 8   12.217630   8.0 -5.391798e-11  0.01  0.000014  696.7986
# 9   12.605750   9.0 -5.020442e-11  0.01  0.000014  704.7291
# 10  12.995240  10.0 -5.340919e-11  0.01  0.000014  712.5750
# 11  13.388850   9.0 -9.481824e-11  0.01  0.000014  703.6431
# 12  13.777020   8.0 -1.214745e-10  0.01  0.000014  696.1927
# 13  14.167190   7.0 -1.308853e-10  0.01  0.000015  688.5151
# 14  14.558510   6.0 -1.358196e-10  0.01  0.000015  681.7729
# ...

# %%
gate_sweep2
# Out:
#         Time    Vg         Iㅣeak   Vsd       Isd         R
# 21  17.29797   0.0 -1.371916e-10  0.01  0.000016  643.5284
# 571  234.6094  4.0 -9.858222e-11  0.01  0.000015  661.4067
# ..        ...  ...           ...   ...       ...       ...
# 713  291.3377  4.0 -1.900488e-10  0.01  0.000015  657.8272
# 714  291.7592  3.0 -1.882681e-10  0.01  0.000015  652.3527
# 715  292.1736  2.0 -1.878143e-10  0.01  0.000015  646.6477
# 716  292.5720  1.0 -1.910677e-10  0.01  0.000016  641.3233
# 717  292.9728  0.0 -1.886235e-10  0.01  0.000016  635.2937
#
# [151 rows x 6 columns]

# %% [markdown]
# ### gate sweep 구간 별로 split이 잘 되었음을 확인했으므로 구간별로 색을 달리하여 그래프를 plot 해주자.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already created and named the split DataFrames (df1, df2, df3, ...)
# If not, you can use the code you provided earlier

# Create a list of DataFrames
dfs = [gate_sweep1, gate_sweep2, gate_sweep3, gate_sweep4, gate_sweep5, gate_sweep6, gate_sweep7, gate_sweep8]  # Add more DataFrames as needed

# Plot each DataFrame on the same graph
for i, gate_sweep in enumerate(dfs, start=1):
    plt.plot(gate_sweep['Vg'], gate_sweep['Isd']*1e6, label=f'gate_sweep{i}')

# Customize the plot
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()
plt.title('Vg vs Isd for gate sweep')

# Show the plot
plt.show()

# %% [markdown]
# ### 위의 그래프는 여러 그래프가 겹쳐져있어 hysteresis가 보이지 않으므로 gate sweep 구간 1, 2, 3, ... 별로 따로 그려보며 hysteresis를 살펴보자.

# %%
import matplotlib.pyplot as plt

# %%
# gate-sweep 1구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep1['Vg'], gate_sweep1['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %%
# gate-sweep 2구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep2['Vg'], gate_sweep2['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %%
# gate-sweep 3구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep3['Vg'], gate_sweep3['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %%
# gate-sweep 4구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep4['Vg'], gate_sweep4['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %%
# gate-sweep 5구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep5['Vg'], gate_sweep5['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %%
# gate-sweep 6구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep6['Vg'], gate_sweep6['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %%
# gate-sweep 7구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep7['Vg'], gate_sweep7['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %%
# gate-sweep 8구간
# Vg에 대한 Isd 그래프 플로팅
plt.plot(gate_sweep8['Vg'], gate_sweep8['Isd']*1e6, marker='o', linestyle='-', color='red', label='Drain Voltage: 0.01V')

# 축 레이블 및 제목 추가
plt.xlabel('$V_g$ (V)')
plt.ylabel('$I_{sd}$ (μA)')
plt.legend()

# 그래프 표시
plt.show()

# %% [markdown]
# # mobility를 계산해보자
#
# ## Drude model
#  J = n * e * (mobility) * E
#  선형의 관계일 경우에는 이렇게 바로 구해도 가능
# ##
# n = Cg * Vg / e
#
# (mobility) = (1 / Cg) * (d Isd/ d Vg) * (1 / Vsd) * ((Length) / (Width))
#
# (Length) / (Width) ~ 0.8

# %% [markdown]
# ### dataset = gate_sweep1

# %%
# Calculate dI/dVg
gate_sweep1['dI/dVg'] = np.gradient(gate_sweep1['Isd']*1e6, gate_sweep1['Vg'])
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:1244: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:1250: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# <ipython-input-39-f173aff77f35>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gate_sweep1['dI/dVg'] = np.gradient(gate_sweep1['Isd']*1e6, gate_sweep1['Vg'])

# %%
## Apply Savitzky-Golay filter
from scipy.signal import savgol_filter

window_lenght = 5
polyorder = 2
gate_sweep1['dI/dVg_smoothing'] = savgol_filter(gate_sweep1['dI/dVg'], window_lenght, polyorder)

# Plotting original dI/dVg
plt.figure()
plt.plot(gate_sweep1['Vg'], gate_sweep1['dI/dVg'], label='dI/dVg Original')
plt.xlabel('Gate Voltage (Vg)')
plt.ylabel('dI/dVg')
plt.title('Original vs. Smoothed dI/dVg')
plt.legend()
# Out:
# <ipython-input-40-b037e9a41898>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gate_sweep1['dI/dVg_smoothing'] = savgol_filter(gate_sweep1['dI/dVg'], window_lenght, polyorder)

# %%
import matplotlib.pyplot as plt

# Constants
Cg = 1.15 * 1e-8  # F/cm

# Normalize the RGB values (252, 103, 54) to [0, 1]
color_normalized = (100/255, 103/255, 54/255)

# Ensure you're using 'df1['Vsd']' if 'Vsd' values are relevant to the sliced portion 'df1'
# Calculate carrier mobility
# Adjusting the formula based on the assumption above
carrier_mobility = 0.8/ Cg * gate_sweep1['dI/dVg']/gate_sweep1['Vsd']
# Plotting
plt.figure()
plt.plot(gate_sweep1['Vg'], carrier_mobility, label='Carrier Mobility', color='red')
plt.xlabel('Gate Voltage (Vg)')
plt.ylabel('Carrier Mobility (cm$^2$/Vs)')
plt.title('Carrier Mobility vs. Gate Voltage')
plt.legend()
plt.show()

# %% [markdown]
# ### dataset = gate_sweep8

# %%
# Calculate dI/dVg
gate_sweep8['dI/dVg'] = np.gradient(gate_sweep8['Isd']*1e6, gate_sweep8['Vg'])
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:1244: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:1250: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# <ipython-input-43-ec6680b73c00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gate_sweep8['dI/dVg'] = np.gradient(gate_sweep8['Isd']*1e6, gate_sweep8['Vg'])

# %%
## Apply Savitzky-Golay filter
from scipy.signal import savgol_filter

window_lenght = 5
polyorder = 2
gate_sweep8['dI/dVg_smoothing'] = savgol_filter(gate_sweep8['dI/dVg'], window_lenght, polyorder)
# Out:
# <ipython-input-44-406873150768>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gate_sweep8['dI/dVg_smoothing'] = savgol_filter(gate_sweep8['dI/dVg'], window_lenght, polyorder)

# %%
# Constants
Cg = 1.15 * 1e-8  # F/cm

# Normalize the RGB values (252, 103, 54) to [0, 1]
color_normalized = (100/255, 103/255, 54/255)

# Ensure you're using 'df8['Vsd']' if 'Vsd' values are relevant to the sliced portion 'df8'
# Calculate carrier mobility
# Adjusting the formula based on the assumption above
carrier_mobility = 0.8/ Cg * gate_sweep8['dI/dVg']/gate_sweep8['Vsd']
# Plotting
plt.figure()
plt.plot(gate_sweep8['Vg'], carrier_mobility, label='Carrier Mobility', color='blue')
plt.xlabel('Gate Voltage (Vg)')
plt.ylabel('Carrier Mobility (cm$^2$/Vs)')
plt.title('Carrier Mobility vs. Gate Voltage')
plt.legend()
plt.show()
